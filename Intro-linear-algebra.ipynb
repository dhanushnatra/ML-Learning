# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# april 1 -> first generator stared working -> 1kj/day
# may 1 -> second generator started working -> 4kj/day
#
# 1. april = may power entha ani
# 2. total energy

# %% [markdown]
# april p = n
#
# 30 days between
#
# may p = (n-30)*4

# %% [markdown]
# mayp=aprilp assumed
#
# 4n-120=n
# 3n=120
# n=120/3
# n=40

# %%
n=np.linspace(1,50,100)

april_p=n+0
may_p=(n-30)*4

# %%
fig,ax=plt.subplots()

ax.plot(n,april_p,color="green")
ax.plot(n,may_p,color="brown")
ax.set_xlabel("Time in days")
ax.set_ylabel("power generated")
ax.set_xlim([0,50])
ax.set_ylim([0,50])
ax.axvline(x=40,color="blue",linestyle="--")
ax.axhline(y=40,color="blue",linestyle="--")

# %%
K=np.array([2,1,3])
"L2_norm",np.linalg.norm(K)
# Out:
# ('L2_norm', np.float64(3.7416573867739413))

# %%
x=np.array([-1,1])
y=np.array([1,1])
x.T,y,(np.dot(x,y))
# Out:
# (array([-1,  1]), array([1, 1]), np.int64(0))
